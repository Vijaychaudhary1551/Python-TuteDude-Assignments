# %% [markdown]
# <a href="https://colab.research.google.com/github/Vijaychaudhary1551/Python-TuteDude-Assignments/blob/main/Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #ASSIGNMENT 2:
# Module 3: Control Structures in Python

# %% [markdown]
# Task 1: Check if a Number is Even or Odd
# Problem Statement:  Write a Python program that:
# 1. 	Takes an integer input from the user.
# 2. 	Checks whether the number is even or odd using an if-else statement.
# 3. 	Displays the result accordingly.

# %%
num = int(input("Enter a number: "))
if (num % 2) == 0:
    print(f"{num} is an even number")
else:
    print(f"{num} is an odd number ")
# Out:
# Enter a number: 9
# 9 is an odd number

# %% [markdown]
# Task 2: Sum of Integers from 1 to 50 Using a Loop
#
# Problem Statement: Write a Python program that:
# 1.   Uses a for loop to iterate over numbers from 1 to 50.
# 2.   Calculates the sum of all integers in this range.
# 3.   Displays the final sum.

# %%
total_sum = 0
for i in range(1, 51):
    total_sum += i
print(f"The sum of numbers 1 to 50 is {total_sum}")
# Out:
# The sum of numbers 1 to 50 is 1275
